# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/Creative_Computing/blob/main/homework/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS/CRT 103: Creative Computing and programming
# ## Assignment Chapter 2
#
# ## Name:

# %% [markdown]
# ### Instructions. Refer to Chapter 2: Programming Exercises pg 114.
#
# Please write a working script for the following exercises:
#
# 1, 2, 3, 4, 5, 6, 7, 8, 9, BONUS: 14
#
# ### Use one cell block per exercise. Do not forget to comment your code. Once your code is ready, run it so that your output is displayed. Then, save and export your Jupyter notebook as a PDF. Upload your PDF in Moodle by the deadline.

# %%
#Exercise 1
#Write your code below
# Out:
# Ying Ying

# %%
#Exercise 2
#Write your code below

# %%
#Exercise 3

# %% [markdown]
# ..you can keep adding cell blocks (feel free to delete this cell block)
