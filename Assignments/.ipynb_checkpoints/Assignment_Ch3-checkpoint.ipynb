# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/Creative_Computing/blob/main/homework/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS/CRT 103: Creative Computing and programming
# ## Assignment Chapter 3
#
# ## Name:

# %% [markdown]
# ### Instructions. Refer to Chapter 3: Programming Exercises pg 162.
#
# Please write a working script for the following exercises:
#
# 1, 2, 3, 4, 5, 7, 11, 12, 14, 16.
#
# ### Use one cell block per exercise. Do not forget to comment your code. Upload your Jupyter Notebook in Moodle.

# %%
#Exercise 1
#Write your code below

# %%
#Exercise 2
#Write your code below

# %% [markdown]
# ..you can keep adding cell blocks (feel free to delete this cell block)
