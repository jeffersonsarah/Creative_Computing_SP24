# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/Creative_Computing/blob/main/Lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 3: Formatting
#
# ## Escape Sequences in Strings
# In Python and other programming languages \ followed by a character is an escape sequence. Let us see the most common escape characters:
#
# \n: new line
#
# \t: Tab means
#
# \\: Back slash
#
# \': Single quote (')
#
# \": Double quote (")

# %% [markdown]
# ![image.png](attachment:4de25ab0-fba4-4a9e-bcd6-6c77ed7ce63c.png)

# %%
print("I hope everyone is enjoying Creative Computing.\nAre you ?") # line break
print('Days\tTopics\tExercises') # adding tab space or 4 spaces 
print('Day 1\t2\t9')
print('Day 2\t1\t8')
print('Day 3\t3\t10')
print('Day 4\t2\t9')
print('This is a backslash  symbol (\\)') # To write a backslash
print('In every programming language it starts with \"Hello, World!\"') # to write a double quote inside a single quote
print('A random hard-drive path is C:\\temp\\data')

# %% [markdown]
# ## Formatting
#
# F-strings are a special type of string literal that allow you to format
# values in a variety of ways.
#
# An f-string is a string literal that is enclosed in quotation marks and prefixed with the letter f.
# Here is a very simple example of an f-string:

# %%
print(f'Hello Creative Computing')

# %%
name='Hector'
print(f'Hello {name}.')

#Try some other examples
age = input("What is your age: ") 
print(f'I am {age} years old.')

# %% [markdown]
# ### Formatting values
#
# Use a variable or placeholder:
#
# _placeholder:format-specifier_

# %%
#Working with numbers and decimals
cost = 350
installment = cost / 12
print(f'The monthly installment is {installment}.')
print(f'The monthly installment is {installment:.2f}.')

# %%
#You can insert comma separators within numbers
pop_indiana = 6751340
print(f'Indiana\'s population is {pop_indiana:,.2f}.')

# %%
#Percentages
discount = 0.5
print(f'The discount is {discount:.0%}')

# %%
#Try different formats for different numerical displays
price = 500
discount1 = 0.15
print(f'You are buying a phone for a price of ${price:.2f}. Your discount is {discount1:.0%}.')

# %% [markdown]
# ### Alignment
#
# ![image.png](attachment:5d05ec54-c3fc-443d-ba7c-9bd87ac61516.png)
#
# Designators follow a specific order:
#
# _[alignment]_ _[width]_ _[,]_ _[.precision]_ _[type]_

# %%
print(f'****{name:>40}****')

# %%
print(f'@@@{installment:^15,.2f}@@@')

# %% [markdown]
# ### Exercise
# Write a program that asks the user for the number of males and the number of females registered in a class. The program should display the percentage of males and females in the class.
# Hint: Each percentage can be calculated by dividing each gender by the total number of students. Try different output formats.
