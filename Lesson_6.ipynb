# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/Creative_Computing/blob/main/Lesson_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 6: Repetition Structures - for loop
#
# In Python, a repetition structure, also known as a loop, is used to execute a block of code multiple times. There are two types of loops in Python: the for loop and the while loop.
#
# ### Count-controlled loop

# %%
for variable in [value 1, value 2, value 3, etc]:
    action 1
    action 2
    etc.

# %%
print('I will display the numbers 1 through 5.') #title
for num in [1, 2, 3, 4, 5, 10]: 
    print(num)

# %% [markdown]
# ![image.png](attachment:e7426ee2-6c34-439d-be79-34493ff450e0.png)

# %%
print('I will display some of the best football teams in the world.') #title
for teams in ['Arsenal','Barcelona', 'AC Milan', 'River Plate']: 
    print(teams)

# %% [markdown]
# Using the `range` function with the `for` loop
#
# `range(start (include), end (exclude), step)`

# %%
for x in range(0,24,5):
    print(x)

# %% [markdown]
# ### Example 1.
# Write a loop that prints a table of the first ten numbers and their equivalent squares displayed in two columns.

# %%
# Example 1
print(f'Number\tSquare')
print(f'**************')

for number in range(1,11,1):
    square = number **2
    print(f'{number}\t{square}')

# %% [markdown]
# ### Try it yourself.
#
# Most of the world uses the Metric System for physical measurements. When international students come to study at USA, they struggle with converting from kilometers/hr to miles/hr. Create a chart that compares KPH with MPH. Display speeds from 40 KPH to 150 KPH using increments of 10. Formula: MPH = KPH / 1.609. (Use 1 floating number on display)

# %% [markdown]
# ## Letting the user take control on the loop iteration
# ### Example 2.
# Same as Example 1, but this time the user decides how high does the calculation should go.

# %%
# Example 2
stop = int(input(f'Highest number to square?'))
print(f'Number\tSquare')
print(f'**************')

for number in range(1,stop+1,1):
    square = number **2
    print(f'{number}\t{square}')

# %% [markdown]
# ### Try it for yourself
# Same as your previous "Try it yourself". Now, include at what KPH speed to start, and at which one to stop.

# %%
#Try it yourself

# %% [markdown]
# ## Accumulators and totals
#
# ![image.png](attachment:00e4804b-28bb-4c6c-87c8-ebcf18a1863d.png)
#
# ### Example 3

# %%
#Adding the sum of numbers

max = int(input(f'How many numbers do you wish to add?'))
sum = 0


print(f'This script calculates the addition of {max} numbers you will have to enter.')

for counter in range(max): #when using one argument for range, it will start in 0 and end at the argument
    n = int(input(f'Enter a number: '))
    sum = sum + n
print(f'The total sum is {sum:.1f}.')

# %% [markdown]
# ## Nested Loops
#
# A nested loop is a series of loops that are inside other loops.

# %%
for minutes in range(60):
    for seconds in range(60):
        print(f'{minutes:02d} : {seconds:02d}')

# %% [markdown]
# ### Example 4
# Dr. Seah needs an easy software to calculate his students' final grades. She would like to control the number of students enrolled in the course, and the number of tests each student took. The output should display: Student #, each test score, and the average final grade.

# %%
#Example 4
student = int(input(f'How many students are in your course: '))
test = int(input(f'How many tests are to be calculated: '))


for stu in range(1, student+1,1):
    print(f'Student {stu}:')
    total = 0
    average = 0
    for te in range(1, test +1,1):
        exam = int(input(f'Test {te}: '))
        total = total + exam
    average = total / test
    print(f'Final Grade: {average:.1f}')

# %% [markdown]
# ### Try it yourself
#
# Write a program that predicts the approximate size of a population of organisms. The application should use text boxes to allow the user to enter the starting number of organisms, the average daily population increase (as a percentage), and the number of days the organisms will be left to multiply. For example, assume the user enters the following values:
#
# Starting at Day 1, the number of organisms: 2
#
# Average daily increase: 30%
#
# Number of days to multiply: 10

# %%
#Try it yourself

# %% [markdown]
# Exercise Monday:
#
# The OCU Dinning Hall has commissioned you to develop a small app where students can order specific products from their phones. The idea is to display a standard menu option where student choose what they want to order and displays a total.
#
# The menu should display the following:
#
# “Welcome to the Mighty Oaks Cafeteria. Use the list numbers from the menu to make your order:
#
# 1.       Mighty Oaks Burger: $12
#
# 2.       Cheese Burger: $9
#
# 3.       French fries: $5
#
# 4.       Soda: $3
#
# After ordering an item, the user should be asked if they want to order something else: Yes =1, No=0.
#
# If the user wishes to order something else, the menu should display again with the prompt. If the user decides to finish the order. The total should be displayed.
